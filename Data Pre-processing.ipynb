# %% [markdown]
# **Financial Data Analysis**

# %% [markdown]
# **Problem Definition:** - This dataset contains detailed financial and demographic information of 5,000 individuals, including their income, account balances, transaction history, investment behavior, and loan information. The goal is to analyze and understand individual financial behavior, investment patterns, and risk profiles to support personalized financial decision making. **Dataset source**: Kaggle Datasets

# %% [markdown]
# **Data loading and Initial Overview**

# %% [markdown]
# 1.Installing pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\Irene Fathima\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# 2.Importing pandas and numpy libraries

# %%
import pandas as pd
import numpy as np

# %% [raw]
# 3.To import a dataset using pandas

# %%
df = pd.read_csv('Individual financial profiles.csv')  #this reads a csv file 
df
# Out:
#       Age Occupation Risk Tolerance     Investment Goals Income Level  \
# 0      40     Lawyer           High  Wealth Preservation    $46044.94
# 1      30    Teacher            Low  Wealth Preservation    $57169.50
# 2      37    Teacher            Low          Speculation    $71760.86
# 3      27    Student         Medium          Speculation   $-25488.15
# 4      36   Engineer            Low    Income Generation   $106777.95
# ...   ...        ...            ...                  ...          ...
# 4995   21   Engineer           High    Income Generation    $92640.59
# 4996   20    Student            Low  Wealth Preservation   $100107.46
# 4997   53     Lawyer            Low          Speculation     $6058.18
# 4998   75    Student         Medium               Growth    $76214.25
# 4999   33    Retiree            Low               Growth    $62638.63
#
#                                                 Address Account Balance  \
# ...

# %% [markdown]
# 4.To find Number of rows and columns in the dataset.

# %%
df.shape
# Out:
# (5000, 19)

# %% [markdown]
# There are 5000 rows and 19 columns in the dataset

# %% [markdown]
# 5.To find datatypes of each column

# %%
df.dtypes
# Out:
# Age                         int64
# Occupation                 object
# Risk Tolerance             object
# Investment Goals           object
# Income Level               object
# Address                    object
# Account Balance            object
# Deposits                   object
# Withdrawals                object
# Transfers                  object
# International Transfers    object
# Investments                object
# Loan Amount                object
# Loan Purpose               object
# Employment Status          object
# Loan Term (Months)          int64
# Interest Rate              object
# Loan Status                object
# Transaction Description    object
# dtype: object

# %% [markdown]
# int64 - integer numbers , object - represents text or mixed numbers(e.g.,strings)

# %% [markdown]
# 6.To view your data to printout a few rows to keep a visual reference

# %%
df.head()
# Out:
#    Age Occupation Risk Tolerance     Investment Goals Income Level  \
# 0   40     Lawyer           High  Wealth Preservation    $46044.94
# 1   30    Teacher            Low  Wealth Preservation    $57169.50
# 2   37    Teacher            Low          Speculation    $71760.86
# 3   27    Student         Medium          Speculation   $-25488.15
# 4   36   Engineer            Low    Income Generation   $106777.95
#
#                                             Address Account Balance  \
# 0       7168 Moody Meadow\nHernandezshire, PW 06016       $44653.26
# 1      50001 Hector Square\nWest Luisfurt, MA 51935       $29175.47
# 2       997 James Isle\nNorth Rebeccafurt, RI 13366       $86141.59
# 3  1607 Joshua Camp Apt. 634\nConleymouth, CT 66479        $1000.00
# 4       96690 Campbell Common\nDwaynetown, MI 71857       $77918.97
#
#     Deposits Withdrawals  Transfers International Transfers Investments  \
# 0   $9156.01    $9327.70   $3647.92                  $82.80    $8729.30
# ...

# %% [markdown]
# This provides details of the first five rows

# %% [markdown]
# 7.To see the details of last five rows, we use

# %%
df.tail()
# Out:
#       Age Occupation Risk Tolerance     Investment Goals Income Level  \
# 4995   21   Engineer           High    Income Generation    $92640.59
# 4996   20    Student            Low  Wealth Preservation   $100107.46
# 4997   53     Lawyer            Low          Speculation     $6058.18
# 4998   75    Student         Medium               Growth    $76214.25
# 4999   33    Retiree            Low               Growth    $62638.63
#
#                                                 Address Account Balance  \
# 4995          43377 Brooke Gateway\nKyleville, IL 60381      $100000.00
# 4996  1156 Christopher Mountain Suite 011\nEast Jimm...       $29879.73
# 4997  92818 Mary Garden Suite 343\nGuerramouth, DE 6...        $9673.78
# 4998  6197 Stephanie Circles Apt. 765\nCherylstad, N...       $90780.00
# 4999                   Unit 4064 Box 6179\nDPO AA 30544       $62218.05
#
#        Deposits Withdrawals  Transfers International Transfers Investments  \
# ...

# %% [markdown]
# details of last 5 rows

# %% [markdown]
# 8.To get the details regarding data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      5000 non-null   int64
#  1   Occupation               5000 non-null   object
#  2   Risk Tolerance           5000 non-null   object
#  3   Investment Goals         5000 non-null   object
#  4   Income Level             5000 non-null   object
#  5   Address                  5000 non-null   object
#  6   Account Balance          5000 non-null   object
#  7   Deposits                 5000 non-null   object
#  8   Withdrawals              5000 non-null   object
#  9   Transfers                5000 non-null   object
#  10  International Transfers  5000 non-null   object
#  11  Investments              5000 non-null   object
#  12  Loan Amount              5000 non-null   object
#  13  Loan Purpose             5000 non-null   object
# ...

# %% [markdown]
# This shows the information regarding data, such as number of rows and columns in the dataset, null values present in the dataset, datatypes of each column, memory usage of the dataset.Here shows no null values in the dataset

# %% [markdown]
# 9.describe() function shows the statistical summary of numerical data

# %%
df.describe()
# Out:
#                Age  Loan Term (Months)
# count  5000.000000         5000.000000
# mean     51.875600           36.235200
# std      19.579888           17.014705
# min      18.000000           12.000000
# 25%      35.000000           24.000000
# 50%      52.000000           36.000000
# 75%      69.000000           48.000000
# max      85.000000           60.000000

# %% [markdown]
# It shows the numerical columns with continuous data

# %% [markdown]
# Age distribution: avg age is 52 years.age ranges from 18 to 85 years.Standard deviation is 19.6 suggests a fairly wide age distribution.
# Loan Term Distribution:Average loan term is 36 months. Loan Terms range from 12 to 60 months.

# %% [markdown]
# 10.For column names

# %%
df.columns
# Out:
# Index(['Age', 'Occupation', 'Risk Tolerance', 'Investment Goals',
#        'Income Level', 'Address', 'Account Balance', 'Deposits', 'Withdrawals',
#        'Transfers', 'International Transfers', 'Investments', 'Loan Amount',
#        'Loan Purpose', 'Employment Status', 'Loan Term (Months)',
#        'Interest Rate', 'Loan Status', 'Transaction Description'],
#       dtype='object')

# %% [markdown]
# **Handling Missing Values**

# %% [markdown]
# To check for missing values

# %%
df.isnull()
# Out:
#         Age  Occupation  Risk Tolerance  Investment Goals  Income Level  \
# 0     False       False           False             False         False
# 1     False       False           False             False         False
# 2     False       False           False             False         False
# 3     False       False           False             False         False
# 4     False       False           False             False         False
# ...     ...         ...             ...               ...           ...
# 4995  False       False           False             False         False
# 4996  False       False           False             False         False
# 4997  False       False           False             False         False
# 4998  False       False           False             False         False
# 4999  False       False           False             False         False
#
#       Address  Account Balance  Deposits  Withdrawals  Transfers  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                        0
# Occupation                 0
# Risk Tolerance             0
# Investment Goals           0
# Income Level               0
# Address                    0
# Account Balance            0
# Deposits                   0
# Withdrawals                0
# Transfers                  0
# International Transfers    0
# Investments                0
# Loan Amount                0
# Loan Purpose               0
# Employment Status          0
# Loan Term (Months)         0
# Interest Rate              0
# Loan Status                0
# Transaction Description    0
# dtype: int64

# %% [markdown]
# This shows the number of null values in each column. Here shows no null values so given as zero.

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# This shows total number of null values in the dataset.

# %% [markdown]
# no null values present in the dataset

# %% [markdown]
# **Removing Duplicates**

# %% [markdown]
# Checking for duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# To view duplicate rows

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Occupation, Risk Tolerance, Investment Goals, Income Level, Address, Account Balance, Deposits, Withdrawals, Transfers, International Transfers, Investments, Loan Amount, Loan Purpose, Employment Status, Loan Term (Months), Interest Rate, Loan Status, Transaction Description]
# Index: []

# %%
# no duplicate rows

# %%
df.drop_duplicates(subset=None,keep='first',inplace=False)
# Out:
#       Age Occupation Risk Tolerance     Investment Goals Income Level  \
# 0      40     Lawyer           High  Wealth Preservation    $46044.94
# 1      30    Teacher            Low  Wealth Preservation    $57169.50
# 2      37    Teacher            Low          Speculation    $71760.86
# 3      27    Student         Medium          Speculation   $-25488.15
# 4      36   Engineer            Low    Income Generation   $106777.95
# ...   ...        ...            ...                  ...          ...
# 4995   21   Engineer           High    Income Generation    $92640.59
# 4996   20    Student            Low  Wealth Preservation   $100107.46
# 4997   53     Lawyer            Low          Speculation     $6058.18
# 4998   75    Student         Medium               Growth    $76214.25
# 4999   33    Retiree            Low               Growth    $62638.63
#
#                                                 Address Account Balance  \
# ...

# %% [markdown]
# no duplicates found

# %% [markdown]
# **Correcting Datatypes**

# %%
df['Account Balance'] = pd.to_numeric(df['Account Balance'].replace('[\$,]', '', regex=True))
df
# Out:
#       Age Occupation Risk Tolerance     Investment Goals Income Level  \
# 0      40     Lawyer           High  Wealth Preservation    $46044.94
# 1      30    Teacher            Low  Wealth Preservation    $57169.50
# 2      37    Teacher            Low          Speculation    $71760.86
# 3      27    Student         Medium          Speculation   $-25488.15
# 4      36   Engineer            Low    Income Generation   $106777.95
# ...   ...        ...            ...                  ...          ...
# 4995   21   Engineer           High    Income Generation    $92640.59
# 4996   20    Student            Low  Wealth Preservation   $100107.46
# 4997   53     Lawyer            Low          Speculation     $6058.18
# 4998   75    Student         Medium               Growth    $76214.25
# 4999   33    Retiree            Low               Growth    $62638.63
#
#                                                 Address  Account Balance  \
# ...

# %%
df['Withdrawals'] = pd.to_numeric(df['Withdrawals'].replace('[\$,]', '', regex=True))
df['Deposits'] = pd.to_numeric(df['Deposits'].replace('[\$,]', '', regex=True))
df['Transfers'] = pd.to_numeric(df['Transfers'].replace('[\$,]', '', regex=True))
df['International Transfers'] = pd.to_numeric(df['International Transfers'].replace('[\$,]', '', regex=True))
df['Loan Amount'] = pd.to_numeric(df['Loan Amount'].replace('[\$,]', '', regex=True))
df['Investments'] = pd.to_numeric(df['Investments'].replace('[\$,]', '', regex=True))

# %%
df
# Out:
#       Age Occupation Risk Tolerance     Investment Goals Income Level  \
# 0      40     Lawyer           High  Wealth Preservation    $46044.94
# 1      30    Teacher            Low  Wealth Preservation    $57169.50
# 2      37    Teacher            Low          Speculation    $71760.86
# 3      27    Student         Medium          Speculation   $-25488.15
# 4      36   Engineer            Low    Income Generation   $106777.95
# ...   ...        ...            ...                  ...          ...
# 4995   21   Engineer           High    Income Generation    $92640.59
# 4996   20    Student            Low  Wealth Preservation   $100107.46
# 4997   53     Lawyer            Low          Speculation     $6058.18
# 4998   75    Student         Medium               Growth    $76214.25
# 4999   33    Retiree            Low               Growth    $62638.63
#
#                                                 Address  Account Balance  \
# ...

# %%
df['Income Level'] = pd.to_numeric(df['Income Level'].replace('[\$,]', '', regex=True))

# %%
df['Interest Rate'] = pd.to_numeric(df['Interest Rate'].str.replace('%', ''))

# %% [markdown]
# Numerical columns stored as object which likely contain numbers stored as text or strings is converted

# %%
df['Risk Tolerance'] = df['Risk Tolerance'].astype('category')
df['Occupation'] = df['Occupation'].astype('category')

# %%
df['Investment Goals'] = df['Investment Goals'].astype('category')
df['Loan Status'] = df['Loan Status'].astype('category')

# %%
df['Loan Purpose'] = df['Loan Purpose'].astype('category')
df['Employment Status'] = df['Employment Status'].astype('category')
df['Transaction Description'] = df['Transaction Description'].astype('category')

# %%
df
# Out:
#       Age Occupation Risk Tolerance     Investment Goals Income Level  \
# 0      40     Lawyer           High  Wealth Preservation    $46044.94
# 1      30    Teacher            Low  Wealth Preservation    $57169.50
# 2      37    Teacher            Low          Speculation    $71760.86
# 3      27    Student         Medium          Speculation   $-25488.15
# 4      36   Engineer            Low    Income Generation   $106777.95
# ...   ...        ...            ...                  ...          ...
# 4995   21   Engineer           High    Income Generation    $92640.59
# 4996   20    Student            Low  Wealth Preservation   $100107.46
# 4997   53     Lawyer            Low          Speculation     $6058.18
# 4998   75    Student         Medium               Growth    $76214.25
# 4999   33    Retiree            Low               Growth    $62638.63
#
#                                                 Address Account Balance  \
# ...

# %% [markdown]
# Text columns is converted into category type.

# %% [markdown]
# **Creating derived columns**

# %% [markdown]
# 1.Net flow/Cash flow for each individual can be derived from the data.Cash flow represents the movement of money in an out of an individuals account over a period.

# %%
df['Cash Flow'] = df['Deposits'] - (df['Withdrawals'] + df['Transfers'] + df['International Transfers'])
df
# Out:
#       Age Occupation Risk Tolerance     Investment Goals  Income Level  \
# 0      40     Lawyer           High  Wealth Preservation      46044.94
# 1      30    Teacher            Low  Wealth Preservation      57169.50
# 2      37    Teacher            Low          Speculation      71760.86
# 3      27    Student         Medium          Speculation     -25488.15
# 4      36   Engineer            Low    Income Generation     106777.95
# ...   ...        ...            ...                  ...           ...
# 4995   21   Engineer           High    Income Generation      92640.59
# 4996   20    Student            Low  Wealth Preservation     100107.46
# 4997   53     Lawyer            Low          Speculation       6058.18
# 4998   75    Student         Medium               Growth      76214.25
# 4999   33    Retiree            Low               Growth      62638.63
#
#                                                 Address  Account Balance  \
# ...

# %% [markdown]
# Positive value of cashflow - implies more money coming in than going out or the person is saving money.
# Negative value of cashflow - implies more money is going out or the person is accumulating debt.
# Zero - implies a balanced cashflow. money coming in equals money going out.

# %% [markdown]
# 2.Loan to Income ratio

# %%
df['Loan to Income Ratio'] = df['Loan Amount'] / df['Account Balance']
df
# Out:
#       Age Occupation Risk Tolerance     Investment Goals  Income Level  \
# 0      40     Lawyer           High  Wealth Preservation      46044.94
# 1      30    Teacher            Low  Wealth Preservation      57169.50
# 2      37    Teacher            Low          Speculation      71760.86
# 3      27    Student         Medium          Speculation     -25488.15
# 4      36   Engineer            Low    Income Generation     106777.95
# ...   ...        ...            ...                  ...           ...
# 4995   21   Engineer           High    Income Generation      92640.59
# 4996   20    Student            Low  Wealth Preservation     100107.46
# 4997   53     Lawyer            Low          Speculation       6058.18
# 4998   75    Student         Medium               Growth      76214.25
# 4999   33    Retiree            Low               Growth      62638.63
#
#                                                 Address  Account Balance  \
# ...

# %% [markdown]
# Loan to income ratio measures how large a person's loan is in comparison to their income.
# if the ratio is < 1 - more income than loan-implies low risk
# if the ratio is >1  - less income than loan - implies high risk
# if the ratio is =1 - loan equals to income - implies moderate risk

# %% [markdown]
# 3.Interest amount on loan

# %%
df['Interest Amount'] = (df['Loan Amount'] * (df['Interest Rate'] / 100)) * (df['Loan Term (Months)'] / 12)

# %% [markdown]
# Interest amount can be calculated in this way to understand the true cost.

# %%
df

# %% [markdown]
# **Filtering or Aggregating Data**

# %% [markdown]
# 1.Individuals having highest income

# %%
df[df['Income Level'] > 100000]
# Out:
#       Age Occupation Risk Tolerance     Investment Goals  Income Level  \
# 4      36   Engineer            Low    Income Generation     106777.95
# 6      70    Student           High          Speculation     120054.43
# 32     52     Artist            Low               Growth     110564.54
# 33     35     Lawyer           High          Speculation     104698.91
# 39     75   Engineer           High               Growth     123100.16
# ...   ...        ...            ...                  ...           ...
# 4973   37     Doctor           High               Growth     121389.67
# 4979   73    Retiree            Low          Speculation     105394.75
# 4993   47    Teacher            Low    Income Generation     119478.23
# 4994   30   Engineer         Medium  Wealth Preservation     130332.27
# 4996   20    Student            Low  Wealth Preservation     100107.46
#
#                                                 Address  Account Balance  \
# ...

# %% [markdown]
# 820 individuals have income higher than 100000

# %% [markdown]
# 2.Individuals having high income and age less than 30

# %%
df[(df['Income Level'] > 100000) & (df['Age'] <= 30)]
# Out:
#       Age Occupation Risk Tolerance     Investment Goals  Income Level  \
# 45     18     Artist           High          Speculation     128564.64
# 78     21    Retiree           High          Speculation     120473.06
# 84     22     Doctor         Medium               Growth     108748.71
# 146    29    Student         Medium  Wealth Preservation     115933.67
# 177    21     Doctor            Low               Growth     119749.28
# ...   ...        ...            ...                  ...           ...
# 4880   20     Artist         Medium               Growth     108853.66
# 4923   25    Student           High          Speculation     101811.85
# 4942   25     Doctor           High          Speculation     125088.74
# 4994   30   Engineer         Medium  Wealth Preservation     130332.27
# 4996   20    Student            Low  Wealth Preservation     100107.46
#
#                                                 Address  Account Balance  \
# ...

# %% [markdown]
# 3.Occupation of people having highest income

# %%
df[df['Income Level'] > 100000][['Income Level', 'Occupation']]
# Out:
#       Income Level Occupation
# 4        106777.95   Engineer
# 6        120054.43    Student
# 32       110564.54     Artist
# 33       104698.91     Lawyer
# 39       123100.16   Engineer
# ...            ...        ...
# 4973     121389.67     Doctor
# 4979     105394.75    Retiree
# 4993     119478.23    Teacher
# 4994     130332.27   Engineer
# 4996     100107.46    Student
#
# [820 rows x 2 columns]

# %% [markdown]
# Individuals from all fields score high income

# %% [markdown]
# 4.Top 10 highest income individuals and their occupation

# %%
top_income = df.nlargest(10, 'Income Level')[['Income Level', 'Occupation']]
top_income
# Out:
#       Income Level Occupation
# 1997     185124.37   Engineer
# 2040     183399.49     Lawyer
# 1005     176385.45    Student
# 1361     172857.74    Student
# 3246     172454.81     Doctor
# 1982     169498.69     Doctor
# 472      166915.11     Lawyer
# 2127     166133.81    Retiree
# 2387     164195.00     Lawyer
# 4556     159198.15    Teacher

# %% [markdown]
# 5.Individuals having high loan

# %%
high_loans = df[df['Loan Amount'] >= 50000]
high_loans
# Out:
#       Age Occupation Risk Tolerance     Investment Goals  Income Level  \
# 4      36   Engineer            Low    Income Generation     106777.95
# 5      77     Doctor            Low    Income Generation      59157.22
# 6      70    Student           High          Speculation     120054.43
# 11     55    Retiree         Medium    Income Generation      79685.22
# 12     50    Teacher           High  Wealth Preservation      79642.74
# ...   ...        ...            ...                  ...           ...
# 4988   64     Artist           High  Wealth Preservation      99420.41
# 4993   47    Teacher            Low    Income Generation     119478.23
# 4994   30   Engineer         Medium  Wealth Preservation     130332.27
# 4995   21   Engineer           High    Income Generation      92640.59
# 4996   20    Student            Low  Wealth Preservation     100107.46
#
#                                                 Address  Account Balance  \
# ...

# %% [markdown]
# 6.Individuals coming under High risk category

# %%
df[df['Risk Tolerance'].str.lower() == 'high']
# Out:
#       Age Occupation Risk Tolerance     Investment Goals  Income Level  \
# 0      40     Lawyer           High  Wealth Preservation      46044.94
# 6      70    Student           High          Speculation     120054.43
# 12     50    Teacher           High  Wealth Preservation      79642.74
# 14     69    Teacher           High               Growth      76081.96
# 18     78   Engineer           High  Wealth Preservation      50479.30
# ...   ...        ...            ...                  ...           ...
# 4975   48     Lawyer           High          Speculation      92377.00
# 4976   36     Lawyer           High               Growth      69520.01
# 4988   64     Artist           High  Wealth Preservation      99420.41
# 4989   21     Doctor           High  Wealth Preservation       8131.81
# 4995   21   Engineer           High    Income Generation      92640.59
#
#                                                 Address  Account Balance  \
# ...

# %% [markdown]
# 7.Sum of loan Amount

# %%
df['Loan Amount'].sum()
# Out:
# np.float64(189845998.13)

# %% [markdown]
# 8. Sum of all Income

# %%
df['Income Level'].sum()
# Out:
# np.float64(353443631.54)

# %% [markdown]
# 9.Maximum account balance

# %%
df['Account Balance'].max()
# Out:
# np.float64(100000.0)

# %% [markdown]
# 10.Minimum account balance

# %%
df['Account Balance'].min()
# Out:
# np.float64(1000.0)

# %% [markdown]
# 11.Average of deposits

# %%
df['Deposits'].mean()
# Out:
# np.float64(18524.016957999997)

# %% [markdown]
# 12.Median value

# %%
df['Account Balance'].median()

# %% [markdown]
# 13.Minimum Interest rate

# %%
df['Interest Rate'].min()

# %% [markdown]
# 14.Maximum Interst rate

# %%
df['Interest Rate'].max()

# %% [markdown]
# 15.Individuals doing majority in jobs

# %%
df['Occupation'].mode()

# %% [markdown]
# 16.Number of jobs or unique values in Occupation

# %%
df['Occupation'].nunique()

# %% [markdown]
# 17.Loan status of Individuals

# %%
df['Loan Status'].value_counts()

# %% [markdown]
# 18. Index of Maximum value in income

# %%
df['Income Level'].idxmax()

# %% [markdown]
# 19.Index of Minimum value in income

# %%
df['Income Level'].idxmin()

# %% [markdown]
# 20.Minimum index of loan amount

# %%
df['Loan Amount'].idxmin()

# %% [markdown]
# 21.Average value, maximum value and count of Income of individuals based on their occupation

# %%
df.groupby('Occupation')['Income Level'].agg(['mean', 'max', 'count'])

# %% [markdown]
# 22.Majority people in risk category

# %%
df['Risk Tolerance'].mode()

# %% [markdown]
# 23.avg, max and min values of Income

# %%
df.agg({'Income Level': ['mean', 'max', 'min']})

# %% [markdown]
# 24.Sum , median and standard deviation of Loan Amount

# %%
df.agg({'Loan Amount': ['sum', 'median', 'std']})

# %% [markdown]
# 25.count and unique values in category, deposits

# %%
df.agg({'Deposits': ['count', 'nunique']})

# %% [markdown]
# 26.Average Loan amount per employment status

# %%
df.groupby('Employment Status')['Loan Amount'].mean()

# %% [markdown]
# 27. Average loan amount per risk tolerance and employment status

# %%
df.groupby(['Risk Tolerance', 'Employment Status'])['Loan Amount'].mean()
# Out:
# C:\Users\Irene Fathima\AppData\Local\Temp\ipykernel_2484\3645386894.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Risk Tolerance', 'Employment Status'])['Loan Amount'].mean()
# Risk Tolerance  Employment Status
# High            Employed             37934.397936
#                 Retired              37051.184186
#                 Self-Employed        38360.315985
#                 Unemployed           37935.889577
# Low             Employed             37596.767936
#                 Retired              37307.111335
#                 Self-Employed        38641.890605
#                 Unemployed           39144.265841
# Medium          Employed             37887.543639
#                 Retired              37551.459434
#                 Self-Employed        37432.271505
# ...

# %% [markdown]
# 28.Sum and  average deposits per income level

# %%
df.groupby('Income Level')['Deposits'].agg(['sum', 'mean'])
# Out:
#                    sum      mean
# Income Level
# -33320.97       394.17    394.17
# -31211.06       438.30    438.30
# -25488.15       299.47    299.47
# -25087.86       496.90    496.90
# -18262.59       351.32    351.32
# ...                ...       ...
#  172454.81    13982.16  13982.16
#  172857.74    44325.28  44325.28
#  176385.45    35944.08  35944.08
#  183399.49    23570.93  23570.93
#  185124.37     4846.21   4846.21
#
# [5000 rows x 2 columns]

# %% [markdown]
#  Individuals of each occupation falling under loan status.

# %%
df.pivot_table(index='Occupation', columns='Loan Status', aggfunc='count', values='Income Level')
# Out:
# C:\Users\Irene Fathima\AppData\Local\Temp\ipykernel_2484\1493857534.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='Occupation', columns='Loan Status', aggfunc='count', values='Income Level')
# Loan Status  approved  pending  rejected
# Occupation
# Artist            312      200       190
# Doctor            330      198       195
# Engineer          361      190       211
# Lawyer            299      187       181
# Retiree           289      220       207
# Student           327      205       195
# Teacher           323      200       180

# %% [markdown]
#  Average loan amounts for each Occupation and Risk Tolerance level.

# %%
df.pivot_table(index='Occupation', columns='Risk Tolerance', values='Loan Amount')
# Out:
# C:\Users\Irene Fathima\AppData\Local\Temp\ipykernel_2484\108689399.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='Occupation', columns='Risk Tolerance', values='Loan Amount')
# Risk Tolerance          High           Low        Medium
# Occupation
# Artist          38236.021944  39455.209286  37612.141637
# Doctor          36781.804826  38222.775098  37196.747773
# Engineer        38373.423574  39282.627862  38683.597806
# Lawyer          38029.817336  38645.955971  37764.394101
# Retiree         36699.685485  37555.193931  39100.277880
# Student         37855.255342  37841.655236  37197.916192
# Teacher         38571.425652  36180.929205  38141.600342

# %% [markdown]
# **Converting into Proper case**

# %%
df['Loan Status'] = df['Loan Status'].str.title()
df
# Out:
#       Age Occupation Risk Tolerance     Investment Goals  Income Level  \
# 0      40     Lawyer           High  Wealth Preservation      46044.94
# 1      30    Teacher            Low  Wealth Preservation      57169.50
# 2      37    Teacher            Low          Speculation      71760.86
# 3      27    Student         Medium          Speculation     -25488.15
# 4      36   Engineer            Low    Income Generation     106777.95
# ...   ...        ...            ...                  ...           ...
# 4995   21   Engineer           High    Income Generation      92640.59
# 4996   20    Student            Low  Wealth Preservation     100107.46
# 4997   53     Lawyer            Low          Speculation       6058.18
# 4998   75    Student         Medium               Growth      76214.25
# 4999   33    Retiree            Low               Growth      62638.63
#
#                                                 Address  Account Balance  \
# ...

# %% [markdown]
# **Filtering based on Occupation**

# %%
df_engineer = df[df['Occupation'].str.contains('engineer', case=False, na=False)]
df_engineer
# Out:
#       Age Occupation Risk Tolerance     Investment Goals  Income Level  \
# 4      36   Engineer            Low    Income Generation     106777.95
# 18     78   Engineer           High  Wealth Preservation      50479.30
# 22     60   Engineer         Medium               Growth      47649.79
# 28     77   Engineer            Low    Income Generation      56181.95
# 30     61   Engineer           High  Wealth Preservation      88941.51
# ...   ...        ...            ...                  ...           ...
# 4935   74   Engineer         Medium          Speculation      53889.95
# 4977   85   Engineer         Medium          Speculation      66148.32
# 4982   46   Engineer         Medium  Wealth Preservation      86255.89
# 4994   30   Engineer         Medium  Wealth Preservation     130332.27
# 4995   21   Engineer           High    Income Generation      92640.59
#
#                                                 Address  Account Balance  \
# ...

# %%
df['Income Level'].var()
# Out:
# np.float64(882907027.6664587)

# %%
df['Loan Amount'].std()
# Out:
# np.float64(15085.14656191004)
